# %% [markdown]
# <a href="https://colab.research.google.com/github/priyoislam/Object_Detection_with_numpy/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt

# %%
pil_img = Image.open('image3.jpg')
im = np.array(pil_img)

im2=im.copy()

# print('Pixel type:', im.dtype)
# print('Number of dimensions:', im.ndim)
# print('Image size:', im.shape)
plt.imshow(im)
image=im[105:175,515:587 , :]
plt.imshow(image)
target_color=np.array([252,103,128])
euclidean_distance = 40  # Adjust as needed
# Calculate the lower and upper RGB ranges
lower_range = target_color - euclidean_distance -30
upper_range = target_color + euclidean_distance -15
# Clip the ranges to ensure valid RGB values (0-255)
lower_range = np.clip(lower_range, 0, 255)
upper_range = np.clip(upper_range, 0, 255)
print("Lower RGB Range:", lower_range)
print("Upper RGB Range:", upper_range)


color_present_mask = np.all((image >= lower_range) & (image <= upper_range), axis=2)
# print(color_present_mask)

# if np.any(color_present_mask):
#     print("The color is present within the defined range in the image.")
# else:
#     print("The color is not present within the defined range in the image.")

for x in range(image.shape[0]):
  for y in range(image.shape[1]):
    if color_present_mask[x][y]==True:
      image[x][y]=([255,0,0])

plt.imshow(image)
# Out:
# Lower RGB Range: [182  33  58]
# Upper RGB Range: [255 128 153]
